# %%
print("Nagawa Hairatu")
# Out:
# Nagawa Hairatu

# %%
x="food"
print("I love "+x)
# Out:
# I love food

# %%
name,age,is_new_student="Nagawa","22","True"
print(name,age,is_new_student)
# Out:
# Nagawa 22 True

# %%
price=10
qnty=5.5
print(price)
print(qnty)
# Out:
# 10
# 5.5

# %%
x=7
y=8
print(7*8)
# Out:
# 56

# %%
#print("comments in python")

# %%
print("Enter your name")
name=input()
print("Enter your favorite color")
color=input()
print(name +" likes "+ color)
# Out:
# Enter your name
# Hairatu
# Enter your favorite color
# Black
# Hairatu likes Black

# %%
 x=["banana","matooke","cup","kicopo","girl","omuwala"]
print(x[0]+" "+x[1])
print(x[2]+" "+x[3])
print(x[4]+" "+x[5])
# Out:
# banana matooke
# cup kicopo
# girl omuwala

# %%
z=23%7
print(z)
# Out:
# 2

# %%
y=(5-1)*((7+1)**(3-1))
print(y)
# Out:
# 256

# %%
#numbers
#int,complex,float
x=7
y=5.0
z=6j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
#python casting
x=int(4.0)
y=float(7)
f=str("7")
print(x)
print(type(f))
# Out:
# 4
# <class 'str'>

# %%
#statements and loops
letters=['A','B','C','D','E']
for letter in letters:
    if letter=='D':

        print(letter.lower())
    
else:
    
    print(letter.title())
# Out:
# d
# E

# %%
#checking for equality
car="bmw"
car.upper()=="BMW"
# Out:
# True

# %%
requested_topping='mushrooms'
if requested_topping!='anchovies':
    print("Hold the anchovies")
# Out:
# Hold the anchovies

# %%
#chech multiple conditions
age_0=22
age_1=18
age_0>=21 and age_1<=21
# Out:
# True

# %%
#checking for values in a list
requested_topping=['nmushrooms','onion']
